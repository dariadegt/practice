# %% [markdown]
# ##калькулятор
# пи22-5
# дегтярева да

# %%
dic = {'один':1, 'два':2, 'три':3, 'четыре':4,'пять':5, 'шесть':6,'семь':7,'восемь':8,'девять':9, 'десять':10,
        'одиннацать': 11, 'двенадцать' : 12, 'тринадцать':13,	'четырнадцать':14,'пятнадцать':15, 'шестнадцать':16, 'семнадцать':17,'восемнадцать':18,'девятнадцать':19,
        'двадцать':20,'тридцать':30, 'сорок':40, 'пятьдесят':50, 'шестьдесят': 60, 'семьдесят':70, 'восемьдесят': 80, 'девяносто': 90}    
dic1 = {0 : ' ', 1:'один', 2:'два', 3:'три', 4:'четыре',5:'пять', 6:'шесть',7:'семь',8:'восемь',9:'девять' }
dic10p = {0 : ' ', 11:'одиннацать', 12:'двенадцать', 13:'тринадцать', 14:'четырнадцать',15:'пятнадцать', 16: 'шестнадцать',17: 'семнадцать',18:'восемнадцать',19:'девятнадцать'}
dic_10 = {0 : ' ', 10:'десять' ,20:'двадцать',30:'тридцать', 40:'сорок', 50:'пятьдесят', 60:'шестьдесят', 70:'семьдесят',80:'восемьдесят', 90:'девяносто'}
dic100 = {0 : ' ', 100 : 'сто', 200 :'двести', 300:'триста',400: 'четыреста', 500:'пятьсот',600: 'шестьсот', 700: 'семьсот', 800:'восемьсот', 900:'девятьсот'}
dic1000 = {0 : ' ', 1000 : 'тысяча', 2000: 'две тысячи', 3000: 'три тысячи',4000: 'четыре тысячи', 5000: 'пять тысяч', 6000: 'шесть тысяч', 7000: 'семь тысяч', 8000:'восемь тысяч', 9000: 'девять тысяч', 10000: 'десять тысяч'}

dict_d = {'плюс': '+', 'минус':'-', 'умножить':'*'}
num1 = input('введите словами число 1:')
num2 = input('введите словами число 2:')
dey = input('введите словами действие:')

def num_in_str(dat):
  global sign
  if dat !=0:
    sign = abs(dat)/dat
    pass
  dat = abs(dat)
  ein = dat%10
  dat -= ein
  dec = dat%100
  dat-=dec
  hund = dat%1000
  dat-=hund
  return(ein,dec,hund,dat,sign)

def str_to_num(inf):
    return sum(int(dic[i]) for i in inf.split())

def lst_to_str(lus):
  w1000 = str(dic1000.get(lus[3]))
  w100 = str(dic100.get(lus[2]))
  w10 = str(dic_10.get(lus[1]))
  w1 = str(dic1.get(lus[0]))
  if sign < 0:
    sig = 'минус'
  else:
    sig = ''
  print(sig,w1000, w100 ,w10 ,w1)
  


if dey =='плюс':
  res = str_to_num(num1) + str_to_num(num2)
  print(res)
  print(num_in_str(res))
  sp1 = list(num_in_str(res))
  print(sp1)
  lst_to_str(sp1)
elif dey == 'минус':
  res2 = str_to_num(num1) - str_to_num(num2)
  print(res2)
  print(num_in_str(res2))
  sp0 = list(num_in_str(res2))
  print(sp0)
  lst_to_str(sp0)
elif dey == 'умножить':
  res3 = str_to_num(num1) * str_to_num(num2)
  print(res3)
  sp = list(num_in_str(res3))
  print(sp) 
  lst_to_str(sp)
# Out:
# введите словами число 1:три
# введите словами число 2:два
# введите словами действие:минус
# 1
# (1, 0, 0, 0, 1.0)
# [1, 0, 0, 0, 1.0]
#        один
